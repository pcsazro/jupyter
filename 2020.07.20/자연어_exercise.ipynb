# %%
import nltk

# %%
from konlpy.tag import Twitter

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import numpy as np
from PIL import Image

# %%
import matplotlib.pyplot as plt
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 
    
# %matplotlib inline

# %%
text = open('hansohee.txt', encoding='utf-8').read()

# %%
tw = Twitter()

# %%
token_ko = tw.nouns(text)

# %%
ko = nltk.Text(token_ko, name='댓글')

# %%
plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %%
plt.figure(figsize=(12,6))
ko.dispersion_plot(['엄마','사람','피해자','마음','본인'])

# %%
ko.vocab()
# Out:
# FreqDist({'소희': 372, '엄마': 132, '부모': 112, '돈': 101, '사람': 73, '빚': 71, '자식': 68, '딸': 52, '왜': 42, '피해자': 41, ...})

# %%
ko.concordance('엄마')
# Out:
# Displaying 25 of 132 matches:
# 오히려 소희 더 엄 마가 꼭 전부 소희 죄 엄마 죄인 장윤정 김혜수 엄마 어차피 인연 살 예정 돈 소희 워로 응원
# 오히려 소희 더 엄 마가 꼭 전부 소희 죄 엄마 죄인 장윤정 김혜수 엄마 어차피 인연 살 예정 돈 소희 워로 응원 마음 아주 소희 내 응원
# 로 응원 마음 아주 소희 내 응원 연기 소희 분 관련 소희 소희 너 엄마 빚 이유 천륜 엄마 사람 먼저 천륜 저 엄마 뭐 내 눈앞 시궁창 팍
# 소희 내 응원 연기 소희 분 관련 소희 소희 너 엄마 빚 이유 천륜 엄마 사람 먼저 천륜 저 엄마 뭐 내 눈앞 시궁창 팍 박아 소희 배신 녀
# 분 관련 소희 소희 너 엄마 빚 이유 천륜 엄마 사람 먼저 천륜 저 엄마 뭐 내 눈앞 시궁창 팍 박아 소희 배신 녀 불륜 녀 녀 항상 역 뭔
#  무슨 변제 빚 투하 채권자 소희 답답 곗돈 때 소희 자식 죄 소희 엄마 쓰레기 저 피해자 딸 마음 남 돈 처 인간 사람 딸 소희 빚 투한
# 것 처벌 저런 환경 속 꿋꿋 소희 진짜 소희 응원 화이팅 제발 누구 엄마 누구 아빠 돈 준 사람 소희 무슨 잘못 소희 파이팅 이 소희 전화위
# 소희 니 돈 소희 투자 누구 앙갚음 돈 못 분 계 저 분도 알 소희 엄마 자식 걸 살 저 분도 본인 명줄 이제 조금 소희 목덜미 소희 응원
# 덜미 소희 응원 송혜교 소희 소희 전성 시대 소희 완전 피해자 소희 엄마 돈 소희 무조건 매도 채권자 문제 엄마 란 사람 최소한 자식 의무
# 시대 소희 완전 피해자 소희 엄마 돈 소희 무조건 매도 채권자 문제 엄마 란 사람 최소한 자식 의무 왜 빚 대신 하나 부모 천륜 저 자식 왜
#  소희 가정 이제 겨우 빛 빚투 본인 잘못 사기 친 분 죄값 화이팅 엄마 연 부모 수도 소희 부모 인정 딸 딸 사채 몸값 수도 생각 자기 딸
# 모 돈 목적 다른 걸 요구 때문 반드시 도대체 왜 애 이용 짓 진심 엄마 소희 이 학대 뭐 엄마 돈 준 사람 이자 윈윈 보아 보이지 소희 엄
# ...

# %%
data = ko.vocab().most_common(150)
wordcloud = WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.2,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', font_path=path, max_words=2000, mask=image,
              )
wc = wc.generate(text)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
