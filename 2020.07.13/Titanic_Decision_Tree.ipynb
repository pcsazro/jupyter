# %% [markdown]
# # 1. 생존자 예측 프로그램

# %% [markdown]
# 필요한 라이브러리 import

# %% [markdown]
# 처음 설치할 경우
# !pip install library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  # inline = notebook 한줄에 matplot의 정보를 집어 넣겠다
# Out:
# UsageError: unrecognized arguments: # inline = notebook 한줄에 matplot의 정보를 집어 넣겠다

# %% [markdown]
# # 2. 데이터 수집

# %%
raw_data = pd.read_excel('../data/titanic.xls')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# - object = String
# - int64 = 64bit 영역의 int
# - dtypes = 각 type의 개수

# %%
raw_data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
raw_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
raw_data['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))

raw_data['survived'].value_counts().plot.pie(explode=[0,0.1],
                                             autopct='%1.2f%%',ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('survived', data=raw_data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
raw_data['age'].hist(bins=30, figsize=(18,8))

# %%
raw_data.groupby('pclass').mean()
# Out:
#         survived        age     sibsp     parch       fare        body
# pclass
# 1       0.619195  39.159918  0.436533  0.365325  87.508992  162.828571
# 2       0.429603  29.506705  0.393502  0.368231  21.179196  167.387097
# 3       0.255289  24.816367  0.568406  0.400564  13.302889  155.818182

# %%
raw_data.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055513 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055513  1.000000 -0.243699 -0.150917  0.178739  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178739  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(raw_data.corr(), linewidths=0.01, square=True,
            annot=True, cmap=plt.cm.coolwarm, linecolor="green")
plt.title('Correlation between features')
plt.show()

# %% [markdown]
# ## 카테고리를 나누기
# - pd.cut을 사용

# %%
raw_data['age_cate'] = pd.cut(
                                        raw_data['age'],
                                        bins=[0,3,7,15,30,60,100],
                                        include_lowest=True,
                                        labels=['baby','children','teenager',
                                                    'young','adult','old']
)
raw_data['age_cate']
# Out:
# 0          young
# 1           baby
# 2           baby
# 3          young
# 4          young
#           ...
# 1304    teenager
# 1305         NaN
# 1306       young
# 1307       young
# 1308       young
# Name: age_cate, Length: 1309, dtype: category
# Categories (6, object): [baby < children < teenager < young < adult < old]

# %%
raw_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest  age_cate
# 0       NaN                     St Louis, MO     young
# 1       NaN  Montreal, PQ / Chesterville, ON      baby
# 2       NaN  Montreal, PQ / Chesterville, ON      baby
# 3     135.0  Montreal, PQ / Chesterville, ON     young
# 4       NaN  Montreal, PQ / Chesterville, ON     young
# ...     ...                              ...       ...
# 1304  328.0                              NaN  teenager
# 1305    NaN                              NaN       NaN
# 1306  304.0                              NaN     young
# 1307    NaN                              NaN     young
# 1308    NaN                              NaN     young
#
# [1309 rows x 15 columns]

# %% [markdown]
# ### age_cate -> group -> mean

# %%
raw_data.groupby('age_cate').mean()
# Out:
#             pclass  survived        age     sibsp     parch       fare  \
# age_cate
# baby      2.585366  0.634146   1.540651  1.487805  1.365854  29.615346
# children  2.640000  0.640000   5.160000  1.760000  1.360000  31.022828
# teenager  2.632653  0.489796  11.540816  1.734694  1.163265  38.390904
# young     2.412955  0.368421  23.389676  0.352227  0.236842  27.313140
# adult     1.893564  0.423267  41.548267  0.376238  0.405941  47.141986
# old       1.545455  0.242424  65.393939  0.303030  0.363636  60.248309
#
#                 body
# age_cate
# baby        4.000000
# children         NaN
# teenager  132.000000
# young     169.720930
# adult     154.777778
# old       185.600000

# %% [markdown]
# 막대그래프(barplot)는 평균(mean)을 사용한다.

# %%
plt.figure(figsize=[14,4])

plt.subplot(131)  # 한 줄에 3개의 그래프 첫번째
sns.barplot('pclass','survived',data=raw_data)

# age_cate
plt.subplot(132)  # 한 줄에 3개의 그래프 두번째
sns.barplot('age_cate','survived',data=raw_data)

# sex
plt.subplot(133)  # 한 줄에 3개의 그래프 세번째
sns.barplot('sex','survived',data=raw_data)

plt.show()

# %% [markdown]
# ## 구명 보트의 번호가 있는 사람들의 생존률 계산

# %%
boat_survivors = raw_data[raw_data['boat'].notnull()]

# %%
boat_survivors
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1260       3         1                          Turja, Miss. Anna Sofia
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1299       3         0                              Yasbeck, Mr. Antoni
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S
# 5       male  48.0000      0      0   19952   26.5500      E12        S
# 6     female  63.0000      1      0   13502   77.9583       D7        S
# 8     female  53.0000      2      0   11769   51.4792     C101        S
# ...      ...      ...    ...    ...     ...       ...      ...      ...
# 1260  female  18.0000      0      0    4138    9.8417      NaN        S
# 1261  female  63.0000      0      0    4134    9.5875      NaN        S
# 1277    male  22.0000      0      0    2658    7.2250      NaN        C
# 1286  female  38.0000      0      0    2688    7.2292      NaN        C
# 1299    male  27.0000      1      0    2659   14.4542      NaN        C
#
#        boat  body                        home.dest age_cate
# 0         2   NaN                     St Louis, MO    young
# 1        11   NaN  Montreal, PQ / Chesterville, ON     baby
# 5         3   NaN                     New York, NY    adult
# 6        10   NaN                       Hudson, NY      old
# 8         D   NaN              Bayside, Queens, NY    adult
# ...     ...   ...                              ...      ...
# 1260     15   NaN                              NaN    young
# 1261     15   NaN                              NaN      old
# 1277  13 15   NaN                              NaN    young
# 1286      C   NaN                              NaN    adult
# 1299      C   NaN                              NaN    young
#
# [486 rows x 15 columns]

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))

boat_survivors['survived'].value_counts().plot.pie(explode=[0,0.1],
                                             autopct='%1.2f%%',ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('survived', data=boat_survivors,ax=ax[1])
ax[1].set_title('Survived')

plt.show()

# %% [markdown]
# # 생존자 예측

# %% [markdown]
# ### 필요한 데이터 추출

# %%
train_pre = raw_data[['survived','pclass','sex','age','sibsp','parch','fare']]
train_pre.head()
# Out:
#    survived  pclass     sex      age  sibsp  parch      fare
# 0         1       1  female  29.0000      0      0  211.3375
# 1         1       1    male   0.9167      1      2  151.5500
# 2         0       1  female   2.0000      1      2  151.5500
# 3         0       1    male  30.0000      1      2  151.5500
# 4         0       1  female  25.0000      1      2  151.5500

# %% [markdown]
# ### 추출한 데이터에서 null값 제외

# %%
train_pre = train_pre[train_pre['age'].notnull()]
train_pre = train_pre[train_pre['sibsp'].notnull()]
train_pre= train_pre[train_pre['parch'].notnull()]
train_pre = train_pre[train_pre['fare'].notnull()]
train_pre = train_pre[train_pre['sex'].notnull()]
train_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1045 entries, 0 to 1308
# Data columns (total 7 columns):
# survived    1045 non-null int64
# pclass      1045 non-null int64
# sex         1045 non-null object
# age         1045 non-null float64
# sibsp       1045 non-null int64
# parch       1045 non-null int64
# fare        1045 non-null float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 65.3+ KB

# %%
tmp = []
for each in train_pre['sex']:
    if each == 'female':
        tmp.append(0)
    elif each == 'male':
        tmp.append(1)
    else:
        tmp.append(np.nan)

# %%
train_pre['sex'] = tmp
train_pre.head()
# Out:
#    survived  pclass  sex      age  sibsp  parch      fare
# 0         1       1    0  29.0000      0      0  211.3375
# 1         1       1    1   0.9167      1      2  151.5500
# 2         0       1    0   2.0000      1      2  151.5500
# 3         0       1    1  30.0000      1      2  151.5500
# 4         0       1    0  25.0000      1      2  151.5500

# %%
train_pre['sex'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1301    False
# 1304    False
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1045, dtype: bool

# %%
train_pre['pclass'] = train_pre['pclass'].astype('float')
train_pre['sex'] = train_pre['sex'].astype('float')
train_pre['sibsp'] = train_pre['sibsp'].astype('float')
train_pre['parch'] = train_pre['parch'].astype('float')
train_pre['fare'] = train_pre['fare'].astype('float')
train_pre['survied'] = train_pre['survived'].astype('float')
train_pre.head()
# Out:
#    survived  pclass  sex      age  sibsp  parch      fare  survied
# 0         1     1.0  0.0  29.0000    0.0    0.0  211.3375      1.0
# 1         1     1.0  1.0   0.9167    1.0    2.0  151.5500      1.0
# 2         0     1.0  0.0   2.0000    1.0    2.0  151.5500      0.0
# 3         0     1.0  1.0  30.0000    1.0    2.0  151.5500      0.0
# 4         0     1.0  0.0  25.0000    1.0    2.0  151.5500      0.0

# %%
train_pre2 = train_pre[['pclass','sex','age','sibsp','parch','fare']]
train_pre2.head()
# Out:
#    pclass  sex      age  sibsp  parch      fare
# 0     1.0  0.0  29.0000    0.0    0.0  211.3375
# 1     1.0  1.0   0.9167    1.0    2.0  151.5500
# 2     1.0  0.0   2.0000    1.0    2.0  151.5500
# 3     1.0  1.0  30.0000    1.0    2.0  151.5500
# 4     1.0  0.0  25.0000    1.0    2.0  151.5500

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(train_pre2, 
                                                    train_pre[['survied']], 
                                                    test_size=0.2, 
                                                    random_state=13)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836 entries, 996 to 378
# Data columns (total 6 columns):
# pclass    836 non-null float64
# sex       836 non-null float64
# age       836 non-null float64
# sibsp     836 non-null float64
# parch     836 non-null float64
# fare      836 non-null float64
# dtypes: float64(6)
# memory usage: 45.7 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 699 to 1025
# Data columns (total 6 columns):
# pclass    209 non-null float64
# sex       209 non-null float64
# age       209 non-null float64
# sibsp     209 non-null float64
# parch     209 non-null float64
# fare      209 non-null float64
# dtypes: float64(6)
# memory usage: 11.4 KB

# %% [markdown]
# 섞여있는 index를 정렬 후 제거

# %%
X_train = X_train.reset_index()
X_train = X_train.drop(['index'], axis=1)

X_test = X_test.reset_index()
X_test = X_test.drop(['index'], axis=1)

Y_train = Y_train.reset_index()
Y_train = Y_train.drop(['index'], axis=1)

Y_train = Y_train.reset_index()
Y_train = Y_train.drop(['index'], axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(max_depth=3, random_state=13)
tree_clf.fit(X_train, Y_train)

print('Scroe :', format(tree_clf.score(X_train,Y_train)))
# Out:
# Scroe : 0.8074162679425837

# %%
from sklearn.metrics import accuracy_score

Y_pred = tree_clf.predict(X_test)
print("Test Accuracy is ", accuracy_score(Y_test, Y_pred)*100)
# Out:
# Test Accuracy is  77.99043062200957

# %% [markdown]
# 문제지 = pclass, sex, age, sibsp, parch, fare

# %%
me =[3., 1., 33., 0., 0., 10.]

# %%
tree_clf.predict_proba([me])
# Out:
# array([[0.86910995, 0.13089005]])

# %%
from sklearn.tree import export_graphviz
export_graphviz(
        tree_clf,
        out_file="titanic_decision_tree.dot",
        feature_names=['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare'],
        class_names=['Unsurvived','Survived'],
        rounded=True,
        filled=True
    )

# %%
import graphviz
with open("titanic_decision_tree.dot") as f:
    dot_graph = f.read()
dot = graphviz.Source(dot_graph)
dot.format = 'png'
dot.render(filename='titanic_tree', directory='images/decision_trees', cleanup=True)
dot
# Out:
#   File "<ipython-input-153-c9538878218c>", line 1
#     import graphviz`
#                    ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(raw_data, hue='age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     453     try:
# --> 454         bw = float(bw)
#     455     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-158-8a42b7eb9872> in <module>
# ----> 1 sns.pairplot(raw_data, hue='age')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     281         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     282                                            gridsize, cut, clip,
# --> 283                                            cumulative=cumulative)
#     284     else:
#     285         # Fall back to scipy if missing statsmodels
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     353     fft = kernel == "gau"
#     354     kde = smnp.KDEUnivariate(data)
# --> 355     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     356     if cumulative:
#     357         grid, y = kde.support, kde.cdf
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     140             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     141                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 142                     clip=clip, cut=cut)
#     143         else:
#     144             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     454         bw = float(bw)
#     455     except:
# --> 456         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     457     bw *= adjust
#     458
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     170 #TODO: uncomment checks when we have non-rule of thumb bandwidths for diff. kernels
#     171 #    if kernel == "gauss":
# --> 172     return bandwidth_funcs[bw](x, kernel)
#     173 #    else:
#     174 #        raise ValueError("Only Gaussian Kernels are currently supported")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in bw_scott(x, kernel)
#      53     A = _select_sigma(x)
#      54     n = len(x)
# ---> 55     return 1.059 * A * n ** (-0.2)
#      56
#      57 def bw_silverman(x, kernel=None):
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power
