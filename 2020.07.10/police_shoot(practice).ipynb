# %%
import pandas as pd

# %%
mafs = pd.read_csv('../data/mafs.csv')

# %%
mafs
# Out:
#     Couple  Season               Name  Age Gender  \
# 0        1       1  Jamie Otis-Hehner   27      F
# 1        1       1        Doug Hehner   31      M
# 2        2       1    Cortney Hendrix   26      F
# 3        2       1      Jason Carrion   27      M
# 4        3       1         Monet Bell   33      F
# ..     ...     ...                ...  ...    ...
# 63      32      10       Brandon Reid   34      M
# 64      33      10         Meka Jones   25      F
# 65      33      10     Michael Watson   31      M
# 66      34      10       Mindy Shiben   34      F
# 67      34      10       Zach Justice   32      M
#
#                      Occupation  Decision  Status
# 0                         Nurse         1       1
# 1             Software salesman         1       1
# 2                Make-up artist         1       0
# 3                       Fireman         1       0
# 4   Product development manager         0       0
# ..                          ...       ...     ...
# ...

# %%
mafs.set_index('Couple')
# Out:
#         Season               Name  Age Gender                   Occupation  \
# Couple
# 1            1  Jamie Otis-Hehner   27      F                        Nurse
# 1            1        Doug Hehner   31      M            Software salesman
# 2            1    Cortney Hendrix   26      F               Make-up artist
# 2            1      Jason Carrion   27      M                      Fireman
# 3            1         Monet Bell   33      F  Product development manager
# ...        ...                ...  ...    ...                          ...
# 32          10       Brandon Reid   34      M                Sales Manager
# 33          10         Meka Jones   25      F             Category Analyst
# 33          10     Michael Watson   31      M           Education Director
# 34          10       Mindy Shiben   34      F         Figure Skating Coach
# 34          10       Zach Justice   32      M         Fitness Professional
#
#         Decision  Status
# Couple
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(mafs,hue='Couple')
